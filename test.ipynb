# %%
import geopandas as gpd
import matplotlib.pyplot as plt
import folium

# %%
ghana_roads = gpd.read_file('data/roads_test.geojson')
ghana_roads.head()
# Out:
#   access addr:street         alt_name area bicycle bicycle_road  \
# 0    NaN         NaN         1st Lane  NaN     NaN          NaN
# 1    NaN         NaN   2nd Kuku Close  NaN     NaN          NaN
# 2    NaN         NaN   3rd Kuku Close  NaN     NaN          NaN
# 3    NaN         NaN              NaN  NaN     NaN          NaN
# 4    NaN         NaN  3rd Angola Lane  NaN     NaN          NaN
#
#   brand:wikipedia bridge bridge:name bridge:structure  ... turn:lanes type  \
# 0             NaN    NaN         NaN              NaN  ...        NaN  NaN
# 1             NaN    NaN         NaN              NaN  ...        NaN  NaN
# 2             NaN    NaN         NaN              NaN  ...        NaN  NaN
# 3             NaN    NaN         NaN              NaN  ...        NaN  NaN
# 4             NaN    NaN         NaN              NaN  ...        NaN  NaN
#
#   vehicle wall waterway wheelchair width wikidata wikipedia  \
# 0     NaN  NaN      NaN        NaN   NaN      NaN       NaN
# ...

# %%
ghana_roads.plot()
plt.show()

# %%
m = folium.Map(location=[7.972, -1.406], zoom_start=7)
folium.GeoJson(ghana_roads).add_to(m)
m
